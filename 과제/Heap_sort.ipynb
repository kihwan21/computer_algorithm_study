# %%
# 주어진 틀 삭제 금지
def construct_max_heap(array):
    if array[3] < array[5]:
        array[3], array[5] = array[5], array[3]
    if array[2] < array[4]:
        array[2], array[4] = array[4], array[2]
    if array[1] < array[3]:
        array[1], array[3] = array[3], array[1] 
    if array[0] < array[2]:
        array[0], array[2] = array[2], array[0]
    if array[0] < array[1]:
        array[0], array[1] = array[1], array[0]


def delete_max_heap(array):
    for i in len(array):
        last_index = array[i]
        array = reversed(array) + last_index

array = [12, 11, 13, 5, 6, 7]
print('Original: ' + str(array))

construct_max_heap(array)
print('Max heap: ' + str(array))

delete_max_heap(array)
print('Result: ' + str(array))
# Out:
# Original: [12, 11, 13, 5, 6, 7]
# Max heap: [13, 11, 12, 7, 6, 5]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10584/1016343115.py in <module>
#      24 print('Max heap: ' + str(array))
#      25
# ---> 26 delete_max_heap(array)
#      27 print('Result: ' + str(array))
#
# ~\AppData\Local\Temp/ipykernel_10584/1016343115.py in delete_max_heap(array)
#      14
#      15 def delete_max_heap(array):
# ---> 16     for i in len(array):
#      17         last_index = array[i]
#      18         array = reversed(array) + last_index
#
# TypeError: 'int' object is not iterable

# %%
# 주어진 틀 삭제 금지
def construct_max_heap(array):
    if array[3] < array[5]:
        array[3], array[5] = array[5], array[3]
    if array[2] < array[4]:
        array[2], array[4] = array[4], array[2]
    if array[1] < array[3]:
        array[1], array[3] = array[3], array[1] 
    if array[0] < array[2]:
        array[0], array[2] = array[2], array[0]
    if array[0] < array[1]:
        array[0], array[1] = array[1], array[0]
      

array = [12, 11, 13, 5, 6, 7]

construct_max_heap(array)
print('Max heap: ' + str(array))
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (c:\Users\vlrms\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:301180)
# at w.execute (c:\Users\vlrms\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:300551)
# at w.start (c:\Users\vlrms\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at t.CellExecutionQueue.executeQueuedCells (c:\Users\vlrms\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310950)
# at t.CellExecutionQueue.start (c:\Users\vlrms\.vscode\extensions\ms-toolsai.jupyter-2021.9.1101343141\out\client\extension.js:52:310490)
