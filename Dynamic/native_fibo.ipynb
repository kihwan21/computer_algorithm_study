# %%
def fib(n):
    if n <= 2:
        return 1
    else:
        return fib(n-1) + fib(n-2)

index = 13
print(fib(index))
# Out:
# 233

# %%
# 값이 커지니까 계산 값이 오래 걸림.        #실행 시키지 말기
def fib(n):
    if n <= 2:
        return 1
    else:
        return fib(n-1) + fib(n-2)

index = 100
print(fib(index))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15748/4040792390.py in <module>
#       6
#       7 index = 100
# ----> 8 print(fib(index))
#
# ~\AppData\Local\Temp/ipykernel_15748/4040792390.py in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-1) + fib(n-2)
#       6
#       7 index = 100
#
# ~\AppData\Local\Temp/ipykernel_15748/4040792390.py in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-1) + fib(n-2)
#       6
#       7 index = 100
#
# ~\AppData\Local\Temp/ipykernel_15748/4040792390.py in fib(n)
#       3         return 1
#       4     else:
# ----> 5         return fib(n-1) + fib(n-2)
#       6
#       7 index = 100
#
# ~\AppData\Local\Temp/ipykernel_15748/4040792390.py in fib(n)
#       3         return 1
#       4     else:
# ...
